# %%
import pandas as pd

# Load the dataset (replace 'your_dataset.csv' with your actual file name)
df = pd.read_csv('/winequality-red.csv')

# Display the entire DataFrame (if it's small enough)
print(df)

# Or, if the dataset is large, you can adjust the display options:
pd.set_option('display.max_rows', None)  # To display all rows
pd.set_option('display.max_columns', None)  # To display all columns

# Now display the DataFrame
print(df)

# Optionally, you can reset the options to the default afterward:
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the Wine Quality dataset (assumes you have it as 'winequality-red.csv')
wine_data = pd.read_csv('/winequality-red.csv')
print("First five rows of data:\n", wine_data.head())

# Select a feature (e.g., alcohol content) and the target variable (quality)
X = wine_data[['alcohol']].values
y = wine_data['quality'].values

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# Create and train the model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predict and plot
y_pred = regressor.predict(X_test)
X_pred = regressor.predict(X_train)

plt.scatter(X_train, y_train, color="green")
plt.plot(X_train, X_pred, color="red")
plt.title("Linear Regression on Wine Quality Dataset")
plt.xlabel("Alcohol Content")
plt.ylabel("Quality Score")
plt.show()

plt.scatter(X_test, y_test, color="blue")
plt.plot(X_train, X_pred, color="red")
plt.title("Linear Regression on Wine Quality Dataset")
plt.xlabel("Alcohol Content")
plt.ylabel("Quality Score")
plt.show()

# Print the coefficients and evaluation metrics
print('Coefficients:', regressor.coef_)
print('Intercept:', regressor.intercept_)

print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Coefficient of Determination (R^2 Score):', r2_score(y_test, y_pred))
# Out:
# First five rows of data:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# ...
